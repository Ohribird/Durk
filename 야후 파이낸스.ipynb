# %% [markdown]
# <a href="https://colab.research.google.com/github/Ohribird/Durk/blob/main/%EC%95%BC%ED%9B%84%20%ED%8C%8C%EC%9D%B4%EB%82%B8%EC%8A%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import yfinance as yf


ticker = '005930.KS'
start = "2020-01-01"
end = "2022-12-31"

df = yf.Ticker(ticker).history(start=start, end= end)
fig,ax = plt.subplots(1,1,figsize=(12,4))
ax.plot(df.index, df.Close)
plt.show()

# %%
mkdir helloworld
cd helloworld
git init
# Out:
#   File "<ipython-input-11-9625bd85918f>", line 1
#     mkdir helloworld
#                    ^
# SyntaxError: invalid syntax
